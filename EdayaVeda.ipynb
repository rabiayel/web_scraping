# %%
pip install dtale
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 5.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 4.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [dtale]m15/16 [dtale]ootstrap-components]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/kaleido/_sync_server.py:11: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
import pandas as pd

# %%
df=pd.read_excel('cars.xls')

# %%
d=dtale.show(df)
d.open_browser()

# %%
import webbrowser

# %%
d = dtale.show(df)
url = d._main_url
webbrowser.open(url)
# Out:
# True
